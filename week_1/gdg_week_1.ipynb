# %%
import numpy as np

# %%
import time

# %%
a,b=[1,2],[3,4]
# Out:
# [1, 2]

# %%
arr_a=np.array(a)
arr_b=np.array(b)

# %%
start=time.time()
val=sum(range(3000))
end=time.time()

print("Normal sumation",end-start,val)
arr=np.array(range(3000))
start=time.time()
sum=np.sum(arr)
end=time.time()
print("Numpy sumation",end-start,sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 start=time.time()
# ----> 2 val=sum(range(3000))
#       3 end=time.time()
#       5 print("Normal sumation",end-start,val)
#
# TypeError: 'numpy.int64' object is not callable

# %%
#print(arr_a+arr_b)
a={'val':"re"}
a['val']
# Out:
# 're'

# %%
import pandas as pd
sr=pd.Series([1,2,7,9])
sr.values
df=pd.DataFrame({
    'name':["Jhon","jOo","ooo"],
    'age':[34,45,64]
     })
df.head(3)["name"]
# Out:
# 0    Jhon
# 1     jOo
# 2     ooo
# Name: name, dtype: object
