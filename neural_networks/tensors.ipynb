# %%
import torch

# %%
torch.randn(10,2)
# Out:
# tensor([[ 1.0636, -1.8353],
#         [ 0.1120,  0.5092],
#         [-0.4116,  0.1927],
#         [ 0.4285,  0.9071],
#         [ 0.0457, -0.2251],
#         [-1.1024, -0.0177],
#         [ 0.6721,  1.4934],
#         [ 1.0436,  0.3107],
#         [-0.1058, -1.0071],
#         [-1.7082, -1.0875]])

# %%
import numpy as np
arry=np.array([[1,2,5,2],[4,5,13,3]])

# %%
tensor1=torch.tensor(arry)
tensor2=torch.tensor([1,2,4,4,2,5,1,52,6,23])
tensor3=torch.arange(6)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_3020/3963211277.py in <cell line: 0>()
#       2 tensor2=torch.tensor([1,2,4,4,2,5,1,52,6,23])
#       3 tensor3=torch.arange(6)
# ----> 4 tensor2.reshape(2,3)
#
# RuntimeError: shape '[2, 3]' is invalid for input of size 10

# %%
tensor3.reshape(3,-1)
# Out:
# tensor([[ 1,  2,  4,  4,  2],
#         [ 5,  1, 52,  6, 23]])
